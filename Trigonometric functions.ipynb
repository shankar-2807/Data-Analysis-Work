# %%
import numpy as np

# %%
np.sin(np.radians(30))
# Out:
# 0.49999999999999994

# %%
np.cos(np.radians(30))
# Out:
# 0.8660254037844387

# %%
np.tan(np.radians(30))
# Out:
# 0.5773502691896257

# %% [markdown]
# pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x_sin = np.sin(np.radians((30, 45, 60, 90)))
x_sin
# Out:
# array([0.5       , 0.70710678, 0.8660254 , 1.        ])

# %%
y_cos = np.cos(np.radians((30, 45, 60, 90)))
y_cos
# Out:
# array([8.66025404e-01, 7.07106781e-01, 5.00000000e-01, 6.12323400e-17])

# %%
plt.plot(x_sin, y_cos)
plt.show()
