# %%
import pandas as pd

# %%
stud_res = pd.read_csv("C:/Users/ADMIN/Desktop/FBS/Data Analysis/data set/student_result.csv")
stud_res
# Out:
#    Student ID Section  Class  Study hrs  Sleeping hrs  Social Medic  \
# 0        1001       A     10          2             9             3
# 1        1002       B     10          6             8             2
# 2        1003       A     10          3             8             2
# 3        1004       C     11          0            10             1
# 4        1005       C     11          4             7             2
# 5        1006       A     11         10             7             0
# 6        1007       B     12          4             6             0
# 7        1008       A     12         10             6             2
# 8        1009       B     12          2             8             2
# 9        1010       C     12          6             9             1
#
#    Mobile Game  Percentage
# 0            5          50
# 1            0          80
# 2            4          60
# 3            5          45
# 4            0          75
# 5            0          96
# ...

# %% [markdown]
# ### Group by

# %%
class_res = stud_res.groupby(['Class'])
class_res

# %%
df = pd.DataFrame(class_res)
df
# Out:
#        0                                                  1
# 0  (10,)     Student ID Section  Class  Study hrs  Sleep...
# 1  (11,)     Student ID Section  Class  Study hrs  Sleep...
# 2  (12,)     Student ID Section  Class  Study hrs  Sleep...

# %%
class_res.get_group(10)
class_res
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 class_res.get_group(10)
#       2 class_res
#
# NameError: name 'class_res' is not defined

# %%
class_res.get_group(12)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 class_res.get_group(12)
#
# NameError: name 'class_res' is not defined

# %%
Class_res['study hrs'].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 Class_res['study hrs'].sum()
#
# NameError: name 'Class_res' is not defined

# %%
class_res.count()
# Out:
#        Student ID  Section  Study hrs  Sleeping hrs  Social Medic  \
# Class
# 10              3        3          3             3             3
# 11              3        3          3             3             3
# 12              4        4          4             4             4
#
#        Mobile Game  Percentage
# Class
# 10               3           3
# 11               3           3
# 12               4           4

# %%
class_res['Social Medic'].min()
# Out:
# Class
# 10    2
# 11    0
# 12    0
# Name: Social Medic, dtype: int64

# %%
df
# Out:
#        0                                                  1
# 0  (10,)     Student ID Section  Class  Study hrs  Sleep...
# 1  (11,)     Student ID Section  Class  Study hrs  Sleep...
# 2  (12,)     Student ID Section  Class  Study hrs  Sleep...

# %%
stud_res
# Out:
#    Student ID Section  Class  Study hrs  Sleeping hrs  Social Medic  \
# 0        1001       A     10          2             9             3
# 1        1002       B     10          6             8             2
# 2        1003       A     10          3             8             2
# 3        1004       C     11          0            10             1
# 4        1005       C     11          4             7             2
# 5        1006       A     11         10             7             0
# 6        1007       B     12          4             6             0
# 7        1008       A     12         10             6             2
# 8        1009       B     12          2             8             2
# 9        1010       C     12          6             9             1
#
#    Mobile Game  Percentage
# 0            5          50
# 1            0          80
# 2            4          60
# 3            5          45
# 4            0          75
# 5            0          96
# ...

# %%
class_res['Sleeping hrs'].max()
# Out:
# Class
# 10     9
# 11    10
# 12     9
# Name: Sleeping hrs, dtype: int64

# %%
class_res['Study hrs'].mean()
# Out:
# Class
# 10    3.666667
# 11    4.666667
# 12    5.500000
# Name: Study hrs, dtype: float64

# %%
class_res.groups
# Out:
# {10: [0, 1, 2], 11: [3, 4, 5], 12: [6, 7, 8, 9]}

# %%
list(class_res)
# Out:
# [((10,),
#      Student ID Section  Class  Study hrs  Sleeping hrs  Social Medic  \
#   0        1001       A     10          2             9             3
#   1        1002       B     10          6             8             2
#   2        1003       A     10          3             8             2
#
#      Mobile Game  Percentage
#   0            5          50
#   1            0          80
#   2            4          60  ),
#  ((11,),
#      Student ID Section  Class  Study hrs  Sleeping hrs  Social Medic  \
#   3        1004       C     11          0            10             1
#   4        1005       C     11          4             7             2
#   5        1006       A     11         10             7             0
#
#      Mobile Game  Percentage
#   3            5          45
#   4            0          75
#   5            0          96  ),
#  ((12,),
#      Student ID Section  Class  Study hrs  Sleeping hrs  Social Medic  \
# ...

# %%
dict(list(class_res))
# Out:
# {(10,):    Student ID Section  Class  Study hrs  Sleeping hrs  Social Medic  \
#  0        1001       A     10          2             9             3
#  1        1002       B     10          6             8             2
#  2        1003       A     10          3             8             2
#
#     Mobile Game  Percentage
#  0            5          50
#  1            0          80
#  2            4          60  ,
#  (11,):    Student ID Section  Class  Study hrs  Sleeping hrs  Social Medic  \
#  3        1004       C     11          0            10             1
#  4        1005       C     11          4             7             2
#  5        1006       A     11         10             7             0
#
#     Mobile Game  Percentage
#  3            5          45
#  4            0          75
#  5            0          96  ,
#  (12,):    Student ID Section  Class  Study hrs  Sleeping hrs  Social Medic  \
#  6        1007       B     12          4             6             0
# ...

# %% [markdown]
# ### Handling missing values

# %%
stud_10 = pd.read_csv(C:/Users/ADMIN/Desktop/FBS/Data Analysis/data set)
stud_10
# Out:
#   Cell In[4], line 1
#     stud_10 = pd.read_csv(C:/Users/ADMIN/Desktop/FBS/Data Analysis/data set)
#                            ^
# SyntaxError: invalid syntax

# %%
stud_10.dropna(axis = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 stud_10.dropna(axis = 1)
#
# NameError: name 'stud_10' is not defined

# %%
stud_10.fillna(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 stud_10.fillna(0)
#
# NameError: name 'stud_10' is not defined

# %%
stud_10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 stud_10
#
# NameError: name 'stud_10' is not defined

# %%
stud_10.fillna(method = 'ffill')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 stud_10.fillna(method = 'ffill')
#
# NameError: name 'stud_10' is not defined

# %%
stud_10.fillna(method = 'bfill')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 stud_10.fillna(method = 'bfill')
#
# NameError: name 'stud_10' is not defined

# %%
stud_10.isna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 stud_10.isna()
#
# NameError: name 'stud_10' is not defined

# %%
stud_10.bfill()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 stud_10.bfill()
#
# NameError: name 'stud_10' is not defined

# %%
stud_10.ffill()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 stud_10.ffill()
#
# NameError: name 'stud_10' is not defined

# %%
stud_10.interpolate()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 stud_10.interpolate()
#
# NameError: name 'stud_10' is not defined

# %%
stud = pd.DataFrame(stud_res.gr)
